# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from Perceptron import Perceptron

# %%
data = pd.read_csv("E:\programming\PyLearn-SajjadAemmi\Assignment39\Weather\weatherHistory.csv")
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'], utc=True)
data['Year'] = data['Formatted Date'].dt.year
data['Day'] = data['Formatted Date'].dt.dayofyear
data
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                      7.388889      0.89            14.1197
# 1                      7.227778      0.86            14.2646
# 2                      9.377778      0.89             3.9284
# 3                      5.944444      0.83            14.1036
# 4                      6.977778      0.83            11.0446
# ...                         ...       ...                ...
# 96448                 26.016667      0.43            10.9963
# 96449                 24.583333      0.48            10.0947
# 96450                 22.038889      0.56             8.9838
# 96451                 21.522222      0.60            10.5294
# 96452                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary  Year  Day
# 0                   1015.13       Partly cloudy throughout the day.  2006   90
# 1                   1015.63       Partly cloudy throughout the day.  2006   90
# 2                   1015.94       Partly cloudy throughout the day.  2006   91
# 3                   1016.41       Partly cloudy throughout the day.  2006   91
# 4                   1016.51       Partly cloudy throughout the day.  2006   91
# ...                     ...                                     ...   ...  ...
# 96448               1014.36  Partly cloudy starting in the morning.  2016  253
# 96449               1015.16  Partly cloudy starting in the morning.  2016  253
# 96450               1015.66  Partly cloudy starting in the morning.  2016  253
# 96451               1015.95  Partly cloudy starting in the morning.  2016  253
# 96452               1016.16  Partly cloudy starting in the morning.  2016  253
#
# [96453 rows x 14 columns]

# %%
my_data = data.groupby(['Year', 'Day'])['Temperature (C)'].sum().reset_index()
my_data
# Out:
#       Year  Day  Temperature (C)
# 0     2005  365         0.577778
# 1     2006    1        97.800000
# 2     2006    2       126.316667
# 3     2006    3        56.172222
# 4     2006    4        54.044444
# ...    ...  ...              ...
# 4014  2016  362         6.672222
# 4015  2016  363         5.333333
# 4016  2016  364         4.027778
# 4017  2016  365         2.822222
# 4018  2016  366         2.611111
#
# [4019 rows x 3 columns]

# %%
my_data['Temperature (C)'] = my_data['Temperature (C)'] / 24
my_data
# Out:
#       Year  Day  Temperature (C)
# 0     2005  365         0.024074
# 1     2006    1         4.075000
# 2     2006    2         5.263194
# 3     2006    3         2.340509
# 4     2006    4         2.251852
# ...    ...  ...              ...
# 4014  2016  362         0.278009
# 4015  2016  363         0.222222
# 4016  2016  364         0.167824
# 4017  2016  365         0.117593
# 4018  2016  366         0.108796
#
# [4019 rows x 3 columns]

# %%
plt.figure(figsize=(14, 10))
plt.scatter(my_data['Day'], my_data['Temperature (C)'], marker='*', c='green')
plt.xlabel('Days')
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
X = my_data['Day'].values
Y = my_data['Temperature (C)'].values

X = X.reshape(-1,1)
Y = Y.reshape(-1,1)

print(X.shape, Y.shape)
# Out:
# (4019, 1) (4019, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=33)

# %%
perceptron_regression = Perceptron()
perceptron_regression.fit(X_train, X_test, Y_train, Y_test)

# %%
perceptron_regression = Perceptron(lr_w=0.000001, lr_b=0.0001, epochs=15)
perceptron_regression.fit(X_train, X_test, Y_train, Y_test)

# %%
Y_pred = perceptron_regression.predict(X)

# %%
plt.figure(figsize=(18, 6))
plt.scatter(X, Y, marker='.', c='green')
plt.plot(X, Y_pred, color='purple', lw=4)

# %%
MAE = perceptron_regression.evaluate(X_test, Y_test, loss='MAE')
MSE = perceptron_regression.evaluate(X_test, Y_test, loss='MSE')

print('MAE: ', MAE)
print('MSE: ', MSE)
# Out:
# MAE:  7.677241893552698
# MSE:  83.74662143725087

# %%
npy_data = np.load('weight_and_biases.npy')
npy_data
# Out:
# array([[[0.02714198]],
#
#        [[0.02714198]],
#
#        [[0.02714198]],
#
#        ...,
#
#        [[0.02714198]],
#
#        [[0.02714198]],
#
#        [[0.02714198]]])
